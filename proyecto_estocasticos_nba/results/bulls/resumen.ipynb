# %% [markdown]
# # Resultados: Chicago Bulls (bulls)
#
# Temporadas: 2023-24 a 2024-25 (2 temporadas)
#
# ---
# ## Resumen Estadistico

# %% [markdown]
# | Metrica | Valor |
# |---------|-------|
# | Partidos analizados | 164 |
# | Media (lambda) | 115.03658536585365 |
# | Varianza | 139.4011005353956 |
# | Desviacion estandar | 11.806824320510389 |
# | Minimo | 91.0 |
# | Maximo | 146.0 |
# | Asimetria | 0.07246001772577156 |
# | Curtosis | -0.5467245854745322 |
# | Razon Var/Media | 1.211797969246522 |

# %% [markdown]
# ## Estacionariedad
#
# | Prueba | Estadistico | P-valor | Conclusion |
# | ADF | -7.343 | 0.0000 | Serie ESTACIONARIA (rechaza H0 de raiz unitaria) |
# | KPSS | 0.818 | 0.0100 | Serie NO estacionaria (rechaza H0 de estacionariedad) |

# %% [markdown]
# ## Poisson No Homogeneo
#
# | Metrica | Valor |
# | lambda global | 115.04 |
# | lambda local | 114.05 |
# | lambda visitante | 116.02 |
# | AIC homogeneo | 1280.10 |
# | AIC no homogeneo | 1280.70 |
# | Conclusion | El modelo HOMOGENEO tiene mejor AIC. No hay evidencia suficiente de que lambda varie por local/visitante. |

# %% [markdown]
# ## Cadenas de Markov
#
# | Metrica | Valor |
# | Matriz de transicion P | |
# | P(W\|W) | 0.377 |
# | P(L\|W) | 0.623 |
# | P(W\|L) | 0.570 |
# | P(L\|L) | 0.430 |
# | pi_W estacionaria | 0.478 |
# | pi_L estacionaria | 0.522 |
# | Proporcion W observada | 0.476 |
# | Ultimo resultado | W |
# | P(siguiente = W) | 0.377 |
# | Prediccion | L |

# %% [markdown]
# ## Graficas
#
# Todas las graficas estan en la carpeta `plots/`.

# %% [markdown]
# ### Histograma real vs PMF teorica de Poisson
# ![Histograma real vs PMF teorica de Poisson](plots/histograma_comparativo.png)

# %% [markdown]
# ### CDF empirica vs CDF teorica (escalones)
# ![CDF empirica vs CDF teorica (escalones)](plots/cdf_poisson.png)

# %% [markdown]
# ### Q-Q Plot Poisson
# ![Q-Q Plot Poisson](plots/qq_plot_poisson.png)

# %% [markdown]
# ### Estabilidad de lambda por temporada
# ![Estabilidad de lambda por temporada](plots/media_varianza_por_temporada.png)

# %% [markdown]
# ### Q-Q Plot Exponencial (tiempos entre eventos)
# ![Q-Q Plot Exponencial (tiempos entre eventos)](plots/qq_exponencial.png)

# %% [markdown]
# ### Diagrama de transicion de Markov
# ![Diagrama de transicion de Markov](plots/markov_transiciones.png)
