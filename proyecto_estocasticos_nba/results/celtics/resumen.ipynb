# %% [markdown]
# # Resultados: Boston Celtics (celtics)
#
# Temporadas: 2023-24 a 2024-25 (2 temporadas)
#
# ---
# ## Resumen Estadistico

# %% [markdown]
# | Metrica | Valor |
# |---------|-------|
# | Partidos analizados | 164 |
# | Media (lambda) | 118.42073170731707 |
# | Varianza | 142.01200922070197 |
# | Desviacion estandar | 11.91687917286661 |
# | Minimo | 76.0 |
# | Maximo | 155.0 |
# | Asimetria | -0.15108861057058162 |
# | Curtosis | 0.7458262545666265 |
# | Razon Var/Media | 1.1992157722153918 |

# %% [markdown]
# ## Estacionariedad
#
# | Prueba | Estadistico | P-valor | Conclusion |
# | ADF | -12.412 | 0.0000 | Serie ESTACIONARIA (rechaza H0 de raiz unitaria) |
# | KPSS | 0.794 | 0.0100 | Serie NO estacionaria (rechaza H0 de estacionariedad) |

# %% [markdown]
# ## Poisson No Homogeneo
#
# | Metrica | Valor |
# | lambda global | 118.42 |
# | lambda local | 120.04 |
# | lambda visitante | 116.80 |
# | AIC homogeneo | 1284.76 |
# | AIC no homogeneo | 1283.14 |
# | Conclusion | El modelo NO HOMOGENEO tiene mejor AIC. Lambda varia significativamente entre partidos de local y visitante. |

# %% [markdown]
# ## Cadenas de Markov
#
# | Metrica | Valor |
# | Matriz de transicion P | |
# | P(W\|W) | 0.734 |
# | P(L\|W) | 0.266 |
# | P(W\|L) | 0.846 |
# | P(L\|L) | 0.154 |
# | pi_W estacionaria | 0.761 |
# | pi_L estacionaria | 0.239 |
# | Proporcion W observada | 0.762 |
# | Ultimo resultado | W |
# | P(siguiente = W) | 0.734 |
# | Prediccion | W |

# %% [markdown]
# ## Graficas
#
# Todas las graficas estan en la carpeta `plots/`.

# %% [markdown]
# ### Histograma real vs PMF teorica de Poisson
# ![Histograma real vs PMF teorica de Poisson](plots/histograma_comparativo.png)

# %% [markdown]
# ### CDF empirica vs CDF teorica (escalones)
# ![CDF empirica vs CDF teorica (escalones)](plots/cdf_poisson.png)

# %% [markdown]
# ### Q-Q Plot Poisson
# ![Q-Q Plot Poisson](plots/qq_plot_poisson.png)

# %% [markdown]
# ### Estabilidad de lambda por temporada
# ![Estabilidad de lambda por temporada](plots/media_varianza_por_temporada.png)

# %% [markdown]
# ### Q-Q Plot Exponencial (tiempos entre eventos)
# ![Q-Q Plot Exponencial (tiempos entre eventos)](plots/qq_exponencial.png)

# %% [markdown]
# ### Diagrama de transicion de Markov
# ![Diagrama de transicion de Markov](plots/markov_transiciones.png)
